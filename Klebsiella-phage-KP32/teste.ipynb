# %%
from genome import buscar_genoma

buscar_genoma("pg42489@alunos.uminho.pt","NC_013647.1")

# %%
from genome import buscar_gene

buscar_gene("NC_013647.1","GeneID:8676102")
# Out:
# GeneID:8676102 encontrado
# Posição no ficheiro: 122
# Localização: [36039:37770](+)
# SeqFeature(SimpleLocation(ExactPosition(36039), ExactPosition(37770), strand=1), type='gene', qualifiers=...)

# %%
from genome import buscar_traducao

buscar_traducao("NC_013647.1","GeneID:8676102")
# Out:
# CDS de GeneID:8676102 encontrado
# Posição no ficheiro: 123
# Localização: [36039:37770](+)
# SeqFeature(SimpleLocation(ExactPosition(36039), ExactPosition(37770), strand=1), type='CDS', qualifiers=...)
